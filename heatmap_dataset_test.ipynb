# %% [markdown]
# # Training Blaze model
# PSU ID: zvs5275
#
# Name: Zenan Shi
# ## load dataset

# %%
import torch
import numpy as np
import os
import scipy.io
from PIL import Image
from torchvision.transforms import *
from torch.utils.data import DataLoader

def standardize_label(label, orim):
    label_std = []
    for idx, _ in enumerate(label):
        labelX = label[idx][0] / orim.size[0]
        labelY = label[idx][1] / orim.size[1] 
        label_std.append([labelX, labelY])
    label_std = np.array(label_std)
    # print(label_std)
    return label_std

SHOW_FLAG = False
# guassian generation
def getGaussianMap(joint, heat_size, sigma):
    # by default, the function returns a gaussian map with range [0, 1] of typr float32
    heatmap = np.zeros((heat_size, heat_size), dtype=np.float32)
    tmp_size = sigma * 3
    ul = [int(joint[0] - tmp_size), int(joint[1] - tmp_size)]
    br = [int(joint[0] + tmp_size + 1), int(joint[1] + tmp_size + 1)]
    size = 2 * tmp_size + 1
    x = np.arange(0, size, 1, np.float32)
    y = x[:, np.newaxis]
    x0 = y0 = size // 2
    g = np.exp(-((x - x0) ** 2 + (y - y0) ** 2) / (2 * (sigma ** 2)))
    g.shape
    # usable gaussian range
    g_x = max(0, -ul[0]), min(br[0], heat_size) - ul[0]
    g_y = max(0, -ul[1]), min(br[1], heat_size) - ul[1]
    # image range
    img_x = max(0, ul[0]), min(br[0], heat_size)
    img_y = max(0, ul[1]), min(br[1], heat_size)
    heatmap[img_y[0]:img_y[1], img_x[0]:img_x[1]] = g[g_y[0]:g_y[1], g_x[0]:g_x[1]]
    
    if SHOW_FLAG:
        heatmap *= 255
        heatmap = heatmap.astype(np.uint8)
        cv2.imshow("debug", heatmap)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
#         SHOW_FLAG = False
    
    return heatmap


class PoseImageDataset(torch.utils.data.Dataset):
    def __init__(self, transforms, imagespath='', labelsfilepath=''):

        imgs_list = sorted(os.listdir(os.path.join(imagespath)))
        self.filenames = imgs_list
        self.annotationmat = scipy.io.loadmat(labelsfilepath)

        joints = self.annotationmat['joints']

        joints = np.swapaxes(joints, 2, 0)
        labels = []
        images = []
        self.heatmap_set = np.zeros((2000, 128, 128, 14), dtype=np.float32)

        origin_image_size = []

        for file_idx, file_name in enumerate(imgs_list):
            fn = imgs_list[file_idx]
            orim = Image.open(os.path.join(imagespath,fn))
            origin_image_size.append(orim.size)
            image1 = transforms(orim)
            label = joints[file_idx]
            label = standardize_label(label, orim)
            # print(label)
            for j in range(14):
#                 print(label)
                _joint = (label[j, 0:2] * image_size // 2).astype(np.uint16)
#                 print(_joint)
                self.heatmap_set[file_idx, :, :, j] = getGaussianMap(joint=_joint, heat_size=128, sigma=2)
    
            label = torch.from_numpy(label)
            label1 = label.type(torch.FloatTensor)

            images.append(image1)
            labels.append(label1)

        self.images = images
        self.labels = labels
        self.orim_size = origin_image_size
        print("heatmap_set", len(self.heatmap_set))
        print("images", len(self.images))
        print("orim_size", len(self.orim_size))

    def __getitem__(self, idx):
        return self.images[idx], self.heatmap_set[idx], self.orim_size[idx]
#         return self.images[idx], self.labels[idx], self.orim_size[idx]

    def __len__(self):
        return len(self.filenames)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"using {device}")

image_path = './dataset/lsp/images'
labels_file_path = './dataset/lsp/joints.mat'
# image_size = 128
image_size = 256 # blazepose
# image_size = 196 # deeppose
batch_size = 32
transforms = Compose([
    Resize((image_size,image_size)),
    ToTensor(),
    Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])


dataset = PoseImageDataset(transforms, image_path, labels_file_path)
# print(dataset.images.shape)  #(2000, 14, 3)


total = len(dataset)
print(total)
train_size, test_size = int(total * 0.5), int(total * 0.5)
lengths = [train_size, test_size]
train_dataset, test_dataset = torch.utils.data.dataset.random_split(dataset, lengths)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# using cuda
# heatmap_set 2000
# images 2000
# orim_size 2000
# 2000

# %% [markdown]
# ## heatmap visualization in dataset

# %%
import matplotlib.pyplot as plt
import cv2

# dataiter = iter(train_dataloader)
# # print(dataiter)
# print(len(dataiter.next()))
# images, heatmap, int_labels = dataiter.next()
# heatmap *= 255

img = images[0]
img = img.numpy()
img = np.transpose(img, (1, 2, 0))

plt.imshow(img)

fig = plt.figure(figsize=(18, 12))
for i in range(14):
    ax1 = fig.add_subplot(3, 5, i+1)
    heatmap1 = heatmap.numpy().astype(np.uint8)[i]
    heatmap1 = heatmap1[:,:,0]
    ax1.imshow(heatmap1)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## load BlazeModel

# %%
from BlazeModel import BlazePose

model = BlazePose(14).to(device)
print(model)
# Out:
# BlazePose(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv2_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#       (4): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): ReLU6(inplace=True)
#       (7): Conv2d(72, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#       (4): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=120, out_features=30, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=30, out_features=120, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): ReLU6(inplace=True)
#       (7): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(64, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#       (4): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(200, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_b2): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(64, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#       (4): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(184, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(128, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#       (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=480, out_features=120, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=120, out_features=480, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5_b2): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(128, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#       (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=672, out_features=168, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=168, out_features=672, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv6_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(192, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#       (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=960, out_features=240, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=240, out_features=960, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): BlazeBlock(
#     (depth_conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#     (pointwise_conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv3): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), groups=16)
#     (pointwise_conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv4): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#     (pointwise_conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv5): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), groups=64)
#     (pointwise_conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv6): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), groups=128)
#     (pointwise_conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv7_): Sequential(
#     (0): Conv2d(192, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv8_): Sequential(
#     (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv9_): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv10_): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample0): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample1): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample2): Upsample(scale_factor=2.0, mode=bilinear)
#   (conv11): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): Conv2d(32, 14, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): Sigmoid()
#   )
#   (conv12a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#     (pointwise_conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv13a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), groups=96)
#     (pointwise_conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv14a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), groups=192)
#     (pointwise_conv): Conv2d(192, 288, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv12b): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv13b): Sequential(
#     (0): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv14b): Sequential(
#     (0): Conv2d(192, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv15): Sequential(
#     (0): BlazeBlock(
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (depth_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288)
#       (pointwise_conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU6(inplace=True)
#     )
#     (1): BlazeBlock(
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (depth_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288)
#       (pointwise_conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU6(inplace=True)
#     )
#   )
#   (conv16): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=288, out_features=28, bias=True)
#   )
# )

# %%
model = torch.load("BlazePose.model").to(device)
print(model)
# Out:
# BlazePose(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv2_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#       (4): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): ReLU6(inplace=True)
#       (7): Conv2d(72, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#       (4): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=120, out_features=30, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=30, out_features=120, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): ReLU6(inplace=True)
#       (7): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(64, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=200, bias=False)
#       (4): BatchNorm2d(200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(200, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4_b2): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(64, 184, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(184, 184, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=184, bias=False)
#       (4): BatchNorm2d(184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Identity()
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(184, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(128, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#       (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=480, out_features=120, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=120, out_features=480, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5_b2): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(128, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#       (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=672, out_features=168, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=168, out_features=672, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv6_b1): MobileBottleneck(
#     (conv): Sequential(
#       (0): Conv2d(192, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (3): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#       (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): SEModule(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=960, out_features=240, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=240, out_features=960, bias=False)
#           (3): h_sigmoid()
#         )
#       )
#       (6): h_swish(
#         (sigmoid): h_sigmoid()
#       )
#       (7): Conv2d(960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv2): BlazeBlock(
#     (depth_conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#     (pointwise_conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv3): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), groups=16)
#     (pointwise_conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv4): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#     (pointwise_conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv5): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), groups=64)
#     (pointwise_conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv6): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), groups=128)
#     (pointwise_conv): Conv2d(128, 192, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv7_): Sequential(
#     (0): Conv2d(192, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv8_): Sequential(
#     (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv9_): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv10_): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample0): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample1): Upsample(scale_factor=2.0, mode=bilinear)
#   (upsample2): Upsample(scale_factor=2.0, mode=bilinear)
#   (conv11): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=bilinear)
#     (1): Conv2d(32, 14, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): Sigmoid()
#   )
#   (conv12a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#     (pointwise_conv): Conv2d(32, 96, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv13a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), groups=96)
#     (pointwise_conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv14a): BlazeBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (depth_conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), groups=192)
#     (pointwise_conv): Conv2d(192, 288, kernel_size=(1, 1), stride=(1, 1))
#     (relu): ReLU6(inplace=True)
#   )
#   (conv12b): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv13b): Sequential(
#     (0): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv14b): Sequential(
#     (0): Conv2d(192, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): h_swish(
#       (sigmoid): h_sigmoid()
#     )
#   )
#   (conv15): Sequential(
#     (0): BlazeBlock(
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (depth_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288)
#       (pointwise_conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU6(inplace=True)
#     )
#     (1): BlazeBlock(
#       (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (depth_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288)
#       (pointwise_conv): Conv2d(288, 288, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU6(inplace=True)
#     )
#   )
#   (conv16): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=288, out_features=28, bias=True)
#   )
# )

# %% [markdown]
# ## training and testing function

# %%
def train():
#     model.train()
    loss_value = 0
    for tmp, (images, labels, _) in enumerate(train_dataloader):
        images, labels = images.to(device), labels.to(device)
        predict = model(images)
        predict = predict.view(labels.shape)

        loss_value = lossFunction(predict, labels)
        
        optimizer.zero_grad()
        loss_value.backward()
        optimizer.step()

        if tmp > 0:
            if (tmp % 10) == 0:
                torch.save(model.state_dict(), './chpcurrent_HourGlass.chp')

    return loss_value.item()

def test():
#     model.eval()
    test_loss_total = 0

    images_accuracy = []
    
    with torch.no_grad():
        for images, labels, orim_size in test_dataloader:
            images, labels = images.to(device), labels.to(device)
            predict = model(images)

            predict = predict.view(labels.shape)
            loss_value = lossFunction(predict, labels)

            test_loss_total += loss_value
        test_loss_total /= len(test_dataset)
        return test_loss_total

# %% [markdown]
# ## the main training process

# %%
test_loss, accuracy = [], []

lossFunction = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

EPOCHS = 500
for epoch in range(1, EPOCHS+1):

    train_loss = train()

    test_loss_= test()
    print(f"the {epoch}/{EPOCHS} epoch，training loss is {train_loss}, testing loss is {test_loss_}")

    test_loss1 = test_loss_.detach().cpu().numpy()
    test_loss.append(test_loss1)

model_name = "BlazePose"
torch.save(model, model_name + ".model")
# Out:
# 第1/500次训练，训练损失值为1381.3125, 测试损失值为176.16761779785156
# 第2/500次训练，训练损失值为1381.490966796875, 测试损失值为176.15103149414062
# 第3/500次训练，训练损失值为1383.9822998046875, 测试损失值为176.1826171875
# 第4/500次训练，训练损失值为1385.38037109375, 测试损失值为176.18814086914062
# 第5/500次训练，训练损失值为1379.765869140625, 测试损失值为176.19140625
# 第6/500次训练，训练损失值为1388.098388671875, 测试损失值为176.1631622314453
# 第7/500次训练，训练损失值为1380.07763671875, 测试损失值为176.18435668945312
# 第8/500次训练，训练损失值为1388.0634765625, 测试损失值为176.1847381591797
# 第9/500次训练，训练损失值为1384.597900390625, 测试损失值为176.163818359375
# 第10/500次训练，训练损失值为1387.9425048828125, 测试损失值为176.15830993652344
# 第11/500次训练，训练损失值为1380.586181640625, 测试损失值为176.1898651123047
# 第12/500次训练，训练损失值为1381.1951904296875, 测试损失值为176.17630004882812
# 第13/500次训练，训练损失值为1378.170654296875, 测试损失值为176.2158966064453
# 第14/500次训练，训练损失值为1382.498779296875, 测试损失值为176.1473388671875
# 第15/500次训练，训练损失值为1387.794677734375, 测试损失值为176.1698760986328
# 第16/500次训练，训练损失值为1375.13623046875, 测试损失值为176.18067932128906
# 第17/500次训练，训练损失值为1377.64013671875, 测试损失值为176.15769958496094
# 第18/500次训练，训练损失值为1384.426513671875, 测试损失值为176.182373046875
# 第19/500次训练，训练损失值为1376.4483642578125, 测试损失值为176.1817169189453
# 第20/500次训练，训练损失值为1379.079345703125, 测试损失值为176.1884002685547
# 第21/500次训练，训练损失值为1378.80419921875, 测试损失值为176.16038513183594
# 第22/500次训练，训练损失值为1387.7017822265625, 测试损失值为176.20628356933594
# 第23/500次训练，训练损失值为1375.013916015625, 测试损失值为176.17672729492188
# 第24/500次训练，训练损失值为1377.5694580078125, 测试损失值为176.2036895751953
# 第25/500次训练，训练损失值为1385.154296875, 测试损失值为176.19940185546875
# 第26/500次训练，训练损失值为1381.72265625, 测试损失值为176.17823791503906
# 第27/500次训练，训练损失值为1380.169921875, 测试损失值为176.2024383544922
# 第28/500次训练，训练损失值为1381.26611328125, 测试损失值为176.18084716796875
# 第29/500次训练，训练损失值为1378.0914306640625, 测试损失值为176.18190002441406
# 第30/500次训练，训练损失值为1380.7359619140625, 测试损失值为176.17279052734375
# 第31/500次训练，训练损失值为1382.5970458984375, 测试损失值为176.16334533691406
# 第32/500次训练，训练损失值为1384.80712890625, 测试损失值为176.1898956298828
# 第33/500次训练，训练损失值为1394.30859375, 测试损失值为176.1718292236328
# 第34/500次训练，训练损失值为1382.490234375, 测试损失值为176.19973754882812
# 第35/500次训练，训练损失值为1377.2620849609375, 测试损失值为176.17897033691406
# 第36/500次训练，训练损失值为1393.0875244140625, 测试损失值为176.20640563964844
# 第37/500次训练，训练损失值为1380.7447509765625, 测试损失值为176.18426513671875
# 第38/500次训练，训练损失值为1385.1517333984375, 测试损失值为176.19688415527344
# 第39/500次训练，训练损失值为1379.2822265625, 测试损失值为176.20889282226562
# 第236/500次训练，训练损失值为1373.10888671875, 测试损失值为176.28358459472656
# 第237/500次训练，训练损失值为1377.4852294921875, 测试损失值为176.3002471923828
# 第238/500次训练，训练损失值为1385.4896240234375, 测试损失值为176.28497314453125
# 第239/500次训练，训练损失值为1398.0316162109375, 测试损失值为176.30906677246094
# 第240/500次训练，训练损失值为1392.154052734375, 测试损失值为176.3186492919922
# 第241/500次训练，训练损失值为1388.6318359375, 测试损失值为176.3194122314453
# 第242/500次训练，训练损失值为1371.908203125, 测试损失值为176.30679321289062
# 第243/500次训练，训练损失值为1385.296875, 测试损失值为176.28302001953125
# 第244/500次训练，训练损失值为1383.854736328125, 测试损失值为176.2843475341797
# 第245/500次训练，训练损失值为1382.670166015625, 测试损失值为176.32321166992188
# 第246/500次训练，训练损失值为1376.037841796875, 测试损失值为176.29322814941406
# 第247/500次训练，训练损失值为1383.628173828125, 测试损失值为176.3173828125
# 第248/500次训练，训练损失值为1375.7716064453125, 测试损失值为176.2855224609375
# 第249/500次训练，训练损失值为1386.2568359375, 测试损失值为176.28640747070312
# 第250/500次训练，训练损失值为1376.50048828125, 测试损失值为176.3011932373047
# 第251/500次训练，训练损失值为1378.0673828125, 测试损失值为176.30682373046875
# 第252/500次训练，训练损失值为1378.119140625, 测试损失值为176.29063415527344
# 第253/500次训练，训练损失值为1379.60498046875, 测试损失值为176.29942321777344
# 第254/500次训练，训练损失值为1380.3192138671875, 测试损失值为176.2935028076172
# 第255/500次训练，训练损失值为1381.677978515625, 测试损失值为176.2935333251953
# 第256/500次训练，训练损失值为1389.3623046875, 测试损失值为176.2824249267578
# 第257/500次训练，训练损失值为1385.397705078125, 测试损失值为176.28759765625
# 第258/500次训练，训练损失值为1368.0146484375, 测试损失值为176.32492065429688
# 第259/500次训练，训练损失值为1380.902099609375, 测试损失值为176.2942352294922
# 第260/500次训练，训练损失值为1378.41357421875, 测试损失值为176.33888244628906
# 第261/500次训练，训练损失值为1386.362548828125, 测试损失值为176.32376098632812
# 第262/500次训练，训练损失值为1378.343505859375, 测试损失值为176.31056213378906
# 第263/500次训练，训练损失值为1381.522216796875, 测试损失值为176.30238342285156
# 第264/500次训练，训练损失值为1377.65380859375, 测试损失值为176.30093383789062
# 第265/500次训练，训练损失值为1373.230224609375, 测试损失值为176.32012939453125
# 第266/500次训练，训练损失值为1380.2481689453125, 测试损失值为176.3162078857422
# 第267/500次训练，训练损失值为1384.8389892578125, 测试损失值为176.3358154296875
# 第268/500次训练，训练损失值为1372.419921875, 测试损失值为176.277099609375
# 第269/500次训练，训练损失值为1381.1915283203125, 测试损失值为176.3268585205078
# 第270/500次训练，训练损失值为1377.197998046875, 测试损失值为176.30894470214844
# 第271/500次训练，训练损失值为1386.765869140625, 测试损失值为176.33139038085938
# 第272/500次训练，训练损失值为1383.609619140625, 测试损失值为176.30963134765625
# 第273/500次训练，训练损失值为1383.0751953125, 测试损失值为176.31228637695312
# 第274/500次训练，训练损失值为1381.49951171875, 测试损失值为176.3135223388672
# 第275/500次训练，训练损失值为1385.1693115234375, 测试损失值为176.3443145751953
# 第276/500次训练，训练损失值为1384.6163330078125, 测试损失值为176.3339080810547
# 第277/500次训练，训练损失值为1375.954833984375, 测试损失值为176.31256103515625
# 第278/500次训练，训练损失值为1377.3929443359375, 测试损失值为176.29676818847656
# 第279/500次训练，训练损失值为1391.3731689453125, 测试损失值为176.28858947753906
# 第280/500次训练，训练损失值为1370.775390625, 测试损失值为176.3295135498047
# 第281/500次训练，训练损失值为1391.85107421875, 测试损失值为176.33773803710938
# 第282/500次训练，训练损失值为1387.24365234375, 测试损失值为176.2926483154297
# 第283/500次训练，训练损失值为1379.1768798828125, 测试损失值为176.30712890625
# 第284/500次训练，训练损失值为1379.7314453125, 测试损失值为176.33090209960938
# 第285/500次训练，训练损失值为1389.2733154296875, 测试损失值为176.3395233154297
# 第286/500次训练，训练损失值为1383.563232421875, 测试损失值为176.33108520507812
# 第287/500次训练，训练损失值为1391.7734375, 测试损失值为176.28672790527344
# 第288/500次训练，训练损失值为1373.9652099609375, 测试损失值为176.33932495117188
# 第289/500次训练，训练损失值为1376.80126953125, 测试损失值为176.3322296142578
# 第290/500次训练，训练损失值为1392.7147216796875, 测试损失值为176.34271240234375
# 第291/500次训练，训练损失值为1373.821533203125, 测试损失值为176.32049560546875
# 第292/500次训练，训练损失值为1380.5068359375, 测试损失值为176.33836364746094
# 第293/500次训练，训练损失值为1383.7127685546875, 测试损失值为176.31553649902344
# 第294/500次训练，训练损失值为1378.791015625, 测试损失值为176.32481384277344
# 第295/500次训练，训练损失值为1379.7950439453125, 测试损失值为176.35906982421875
# 第296/500次训练，训练损失值为1374.401611328125, 测试损失值为176.3175811767578
# 第297/500次训练，训练损失值为1377.03076171875, 测试损失值为176.33511352539062
# 第298/500次训练，训练损失值为1380.12353515625, 测试损失值为176.3253631591797
# 第299/500次训练，训练损失值为1385.34619140625, 测试损失值为176.3455810546875
# 第300/500次训练，训练损失值为1378.918212890625, 测试损失值为176.30300903320312
# 第301/500次训练，训练损失值为1375.844970703125, 测试损失值为176.3326416015625
# 第302/500次训练，训练损失值为1375.554443359375, 测试损失值为176.3225555419922
# 第303/500次训练，训练损失值为1376.8629150390625, 测试损失值为176.35740661621094
# 第304/500次训练，训练损失值为1381.28955078125, 测试损失值为176.34530639648438
# 第305/500次训练，训练损失值为1393.3310546875, 测试损失值为176.3182830810547
# 第306/500次训练，训练损失值为1362.436767578125, 测试损失值为176.30050659179688
# 第307/500次训练，训练损失值为1371.60107421875, 测试损失值为176.310791015625
# 第308/500次训练，训练损失值为1379.3221435546875, 测试损失值为176.34716796875
# 第309/500次训练，训练损失值为1386.324462890625, 测试损失值为176.35520935058594
# 第310/500次训练，训练损失值为1375.8775634765625, 测试损失值为176.32089233398438
# 第311/500次训练，训练损失值为1384.48876953125, 测试损失值为176.3542022705078
# 第312/500次训练，训练损失值为1388.9815673828125, 测试损失值为176.33116149902344
# 第313/500次训练，训练损失值为1390.14990234375, 测试损失值为176.32408142089844
# 第314/500次训练，训练损失值为1389.55712890625, 测试损失值为176.33831787109375
# 第315/500次训练，训练损失值为1384.375244140625, 测试损失值为176.3545684814453
# 第316/500次训练，训练损失值为1382.48681640625, 测试损失值为176.30589294433594
# 第317/500次训练，训练损失值为1372.3948974609375, 测试损失值为176.35272216796875
# 第318/500次训练，训练损失值为1385.52783203125, 测试损失值为176.34347534179688
# 第319/500次训练，训练损失值为1380.2025146484375, 测试损失值为176.34140014648438
# 第320/500次训练，训练损失值为1381.9326171875, 测试损失值为176.3301544189453
# 第321/500次训练，训练损失值为1381.3917236328125, 测试损失值为176.30877685546875
# 第322/500次训练，训练损失值为1377.16455078125, 测试损失值为176.3116455078125
# 第323/500次训练，训练损失值为1388.1759033203125, 测试损失值为176.33883666992188
# 第324/500次训练，训练损失值为1385.5380859375, 测试损失值为176.3596649169922
# 第325/500次训练，训练损失值为1395.6846923828125, 测试损失值为176.32977294921875
# 第326/500次训练，训练损失值为1381.983642578125, 测试损失值为176.33175659179688
# 第327/500次训练，训练损失值为1378.2904052734375, 测试损失值为176.33367919921875
# 第328/500次训练，训练损失值为1387.857421875, 测试损失值为176.35040283203125
# 第329/500次训练，训练损失值为1384.185302734375, 测试损失值为176.34039306640625
# 第330/500次训练，训练损失值为1375.20849609375, 测试损失值为176.3206329345703
# 第331/500次训练，训练损失值为1381.415771484375, 测试损失值为176.33920288085938
# 第332/500次训练，训练损失值为1381.346435546875, 测试损失值为176.34017944335938
# 第333/500次训练，训练损失值为1384.303466796875, 测试损失值为176.360107421875
# 第334/500次训练，训练损失值为1383.8822021484375, 测试损失值为176.33094787597656
# 第335/500次训练，训练损失值为1387.985107421875, 测试损失值为176.34494018554688
# 第336/500次训练，训练损失值为1382.492431640625, 测试损失值为176.33291625976562
# 第337/500次训练，训练损失值为1378.278564453125, 测试损失值为176.356689453125
# 第338/500次训练，训练损失值为1386.17236328125, 测试损失值为176.349853515625
# 第339/500次训练，训练损失值为1394.507568359375, 测试损失值为176.35183715820312
# 第340/500次训练，训练损失值为1374.6478271484375, 测试损失值为176.3595733642578
# 第341/500次训练，训练损失值为1376.33251953125, 测试损失值为176.34605407714844
# 第342/500次训练，训练损失值为1381.258544921875, 测试损失值为176.36378479003906
# 第343/500次训练，训练损失值为1375.8411865234375, 测试损失值为176.35418701171875
# 第344/500次训练，训练损失值为1381.038818359375, 测试损失值为176.37164306640625
# 第345/500次训练，训练损失值为1386.890380859375, 测试损失值为176.35752868652344
# 第346/500次训练，训练损失值为1392.560546875, 测试损失值为176.34034729003906
# 第347/500次训练，训练损失值为1390.447998046875, 测试损失值为176.35317993164062
# 第348/500次训练，训练损失值为1392.912353515625, 测试损失值为176.37371826171875
# 第349/500次训练，训练损失值为1388.168701171875, 测试损失值为176.33956909179688
# 第350/500次训练，训练损失值为1385.26806640625, 测试损失值为176.3426971435547
# 第351/500次训练，训练损失值为1377.96142578125, 测试损失值为176.34963989257812
# 第352/500次训练，训练损失值为1391.41259765625, 测试损失值为176.36428833007812
# 第353/500次训练，训练损失值为1388.2274169921875, 测试损失值为176.35565185546875
# 第354/500次训练，训练损失值为1378.03759765625, 测试损失值为176.37564086914062
# 第355/500次训练，训练损失值为1382.96435546875, 测试损失值为176.375244140625
# 第356/500次训练，训练损失值为1389.713623046875, 测试损失值为176.38267517089844
# 第357/500次训练，训练损失值为1378.228759765625, 测试损失值为176.35684204101562
# 第358/500次训练，训练损失值为1383.373291015625, 测试损失值为176.35499572753906
# 第359/500次训练，训练损失值为1389.6602783203125, 测试损失值为176.3563690185547
# 第360/500次训练，训练损失值为1382.142578125, 测试损失值为176.36155700683594
# 第361/500次训练，训练损失值为1387.173095703125, 测试损失值为176.3855743408203
# 第362/500次训练，训练损失值为1385.112060546875, 测试损失值为176.36033630371094
# 第363/500次训练，训练损失值为1375.06787109375, 测试损失值为176.36691284179688
# 第364/500次训练，训练损失值为1383.0120849609375, 测试损失值为176.38595581054688
# 第365/500次训练，训练损失值为1388.302978515625, 测试损失值为176.33468627929688
# 第366/500次训练，训练损失值为1380.81005859375, 测试损失值为176.3761444091797
# 第367/500次训练，训练损失值为1389.1151123046875, 测试损失值为176.35845947265625
# 第368/500次训练，训练损失值为1384.260009765625, 测试损失值为176.38772583007812
# 第369/500次训练，训练损失值为1386.621826171875, 测试损失值为176.3781280517578
# 第370/500次训练，训练损失值为1390.44677734375, 测试损失值为176.3622589111328
# 第371/500次训练，训练损失值为1374.6142578125, 测试损失值为176.3625030517578
# 第372/500次训练，训练损失值为1367.5831298828125, 测试损失值为176.36399841308594
# 第373/500次训练，训练损失值为1373.3448486328125, 测试损失值为176.36607360839844
# 第374/500次训练，训练损失值为1380.318115234375, 测试损失值为176.37220764160156
# 第375/500次训练，训练损失值为1383.74853515625, 测试损失值为176.38722229003906
# 第376/500次训练，训练损失值为1379.910400390625, 测试损失值为176.353271484375
# 第377/500次训练，训练损失值为1395.492919921875, 测试损失值为176.37615966796875
# 第378/500次训练，训练损失值为1380.0980224609375, 测试损失值为176.35743713378906
# 第379/500次训练，训练损失值为1372.6298828125, 测试损失值为176.36709594726562
# 第380/500次训练，训练损失值为1388.413330078125, 测试损失值为176.35899353027344
# 第381/500次训练，训练损失值为1396.330810546875, 测试损失值为176.37535095214844
# 第382/500次训练，训练损失值为1384.781982421875, 测试损失值为176.38491821289062
# 第383/500次训练，训练损失值为1374.80908203125, 测试损失值为176.39508056640625
# 第384/500次训练，训练损失值为1372.34375, 测试损失值为176.31613159179688
# 第385/500次训练，训练损失值为1388.58935546875, 测试损失值为176.35865783691406
# 第386/500次训练，训练损失值为1387.803955078125, 测试损失值为176.38429260253906
# 第387/500次训练，训练损失值为1380.954833984375, 测试损失值为176.37322998046875
# 第388/500次训练，训练损失值为1376.664794921875, 测试损失值为176.41448974609375
# 第389/500次训练，训练损失值为1374.6982421875, 测试损失值为176.3846435546875
# 第390/500次训练，训练损失值为1385.426513671875, 测试损失值为176.3787841796875
# 第391/500次训练，训练损失值为1379.2713623046875, 测试损失值为176.37765502929688
# 第392/500次训练，训练损失值为1377.69580078125, 测试损失值为176.36412048339844
# 第393/500次训练，训练损失值为1384.99267578125, 测试损失值为176.34649658203125
# 第394/500次训练，训练损失值为1385.065185546875, 测试损失值为176.404052734375
# 第395/500次训练，训练损失值为1387.2216796875, 测试损失值为176.39588928222656
# 第396/500次训练，训练损失值为1378.884033203125, 测试损失值为176.38059997558594
# 第397/500次训练，训练损失值为1380.100341796875, 测试损失值为176.37428283691406
# 第398/500次训练，训练损失值为1381.235595703125, 测试损失值为176.38909912109375
# 第399/500次训练，训练损失值为1378.7730712890625, 测试损失值为176.37596130371094
# 第400/500次训练，训练损失值为1379.327392578125, 测试损失值为176.39505004882812
# 第401/500次训练，训练损失值为1381.9354248046875, 测试损失值为176.3931884765625
# 第402/500次训练，训练损失值为1382.042724609375, 测试损失值为176.4326934814453
# 第403/500次训练，训练损失值为1378.2880859375, 测试损失值为176.3994598388672
# 第404/500次训练，训练损失值为1379.6962890625, 测试损失值为176.37472534179688
# 第405/500次训练，训练损失值为1385.85107421875, 测试损失值为176.38046264648438
# 第406/500次训练，训练损失值为1375.7479248046875, 测试损失值为176.39398193359375
# 第407/500次训练，训练损失值为1375.440673828125, 测试损失值为176.39097595214844
# 第408/500次训练，训练损失值为1380.2821044921875, 测试损失值为176.39024353027344
# 第409/500次训练，训练损失值为1381.462890625, 测试损失值为176.4020538330078
# 第410/500次训练，训练损失值为1386.011474609375, 测试损失值为176.40206909179688
# 第411/500次训练，训练损失值为1372.205078125, 测试损失值为176.37188720703125
# 第412/500次训练，训练损失值为1368.7232666015625, 测试损失值为176.39244079589844
# 第413/500次训练，训练损失值为1383.40576171875, 测试损失值为176.383056640625
# 第414/500次训练，训练损失值为1380.108154296875, 测试损失值为176.396484375
# 第415/500次训练，训练损失值为1385.130859375, 测试损失值为176.39930725097656
# 第416/500次训练，训练损失值为1380.929931640625, 测试损失值为176.40013122558594
# 第417/500次训练，训练损失值为1376.48388671875, 测试损失值为176.357421875
# 第418/500次训练，训练损失值为1379.330322265625, 测试损失值为176.39491271972656
# 第419/500次训练，训练损失值为1382.693115234375, 测试损失值为176.37974548339844
# 第420/500次训练，训练损失值为1379.41552734375, 测试损失值为176.39093017578125
# 第421/500次训练，训练损失值为1381.4451904296875, 测试损失值为176.40240478515625
# 第422/500次训练，训练损失值为1377.902099609375, 测试损失值为176.40777587890625
# 第423/500次训练，训练损失值为1381.463134765625, 测试损失值为176.39041137695312
# 第424/500次训练，训练损失值为1383.0721435546875, 测试损失值为176.3827667236328
# 第425/500次训练，训练损失值为1381.479736328125, 测试损失值为176.37950134277344
# 第426/500次训练，训练损失值为1377.295654296875, 测试损失值为176.3846435546875
# 第427/500次训练，训练损失值为1378.5723876953125, 测试损失值为176.42417907714844
# 第428/500次训练，训练损失值为1393.10205078125, 测试损失值为176.38128662109375
# 第429/500次训练，训练损失值为1374.123291015625, 测试损失值为176.4153289794922
# 第430/500次训练，训练损失值为1377.677001953125, 测试损失值为176.3941650390625
# 第431/500次训练，训练损失值为1383.7000732421875, 测试损失值为176.40658569335938
# 第432/500次训练，训练损失值为1387.8150634765625, 测试损失值为176.39453125
# 第433/500次训练，训练损失值为1382.006103515625, 测试损失值为176.38436889648438
# 第434/500次训练，训练损失值为1390.098876953125, 测试损失值为176.39857482910156
# 第435/500次训练，训练损失值为1395.5880126953125, 测试损失值为176.3717041015625
# 第436/500次训练，训练损失值为1389.458740234375, 测试损失值为176.40029907226562
# 第437/500次训练，训练损失值为1375.1962890625, 测试损失值为176.38162231445312
# 第438/500次训练，训练损失值为1381.9794921875, 测试损失值为176.42897033691406
# 第439/500次训练，训练损失值为1387.6268310546875, 测试损失值为176.4217529296875
# 第440/500次训练，训练损失值为1384.518310546875, 测试损失值为176.39395141601562
# 第441/500次训练，训练损失值为1378.943359375, 测试损失值为176.41806030273438
# 第442/500次训练，训练损失值为1384.344970703125, 测试损失值为176.40138244628906
# 第443/500次训练，训练损失值为1387.557373046875, 测试损失值为176.407958984375
# 第444/500次训练，训练损失值为1377.37255859375, 测试损失值为176.4038543701172
# 第445/500次训练，训练损失值为1378.3880615234375, 测试损失值为176.40560913085938
# 第446/500次训练，训练损失值为1380.63623046875, 测试损失值为176.39370727539062
# 第447/500次训练，训练损失值为1383.07275390625, 测试损失值为176.3872528076172
# 第448/500次训练，训练损失值为1379.6387939453125, 测试损失值为176.40289306640625
# 第449/500次训练，训练损失值为1372.20556640625, 测试损失值为176.3996124267578
# 第450/500次训练，训练损失值为1387.99560546875, 测试损失值为176.40225219726562
# 第451/500次训练，训练损失值为1381.24609375, 测试损失值为176.3946075439453
# 第452/500次训练，训练损失值为1378.28955078125, 测试损失值为176.39964294433594
# 第453/500次训练，训练损失值为1377.8446044921875, 测试损失值为176.4099578857422
# 第454/500次训练，训练损失值为1379.960205078125, 测试损失值为176.3951873779297
# 第455/500次训练，训练损失值为1374.216796875, 测试损失值为176.42103576660156
# 第456/500次训练，训练损失值为1379.615966796875, 测试损失值为176.40237426757812
# 第457/500次训练，训练损失值为1369.2451171875, 测试损失值为176.41244506835938
# 第458/500次训练，训练损失值为1384.949462890625, 测试损失值为176.42425537109375
# 第459/500次训练，训练损失值为1370.460693359375, 测试损失值为176.41453552246094
# 第460/500次训练，训练损失值为1377.90771484375, 测试损失值为176.44430541992188
# 第461/500次训练，训练损失值为1378.9727783203125, 测试损失值为176.4148406982422
# 第462/500次训练，训练损失值为1378.36669921875, 测试损失值为176.4181365966797
# 第463/500次训练，训练损失值为1370.1929931640625, 测试损失值为176.4165496826172
# 第464/500次训练，训练损失值为1373.7967529296875, 测试损失值为176.4169464111328
# 第465/500次训练，训练损失值为1387.67236328125, 测试损失值为176.43113708496094
# 第466/500次训练，训练损失值为1398.7073974609375, 测试损失值为176.40635681152344
# 第467/500次训练，训练损失值为1376.625732421875, 测试损失值为176.4144744873047
# 第468/500次训练，训练损失值为1384.4359130859375, 测试损失值为176.4245147705078
# 第469/500次训练，训练损失值为1389.220947265625, 测试损失值为176.44082641601562
# 第470/500次训练，训练损失值为1392.6024169921875, 测试损失值为176.45118713378906
# 第471/500次训练，训练损失值为1379.0244140625, 测试损失值为176.4499969482422
# 第472/500次训练，训练损失值为1388.9437255859375, 测试损失值为176.41978454589844
# 第473/500次训练，训练损失值为1376.130126953125, 测试损失值为176.39833068847656
# 第474/500次训练，训练损失值为1379.752685546875, 测试损失值为176.44044494628906
# 第475/500次训练，训练损失值为1385.3260498046875, 测试损失值为176.46376037597656
# 第476/500次训练，训练损失值为1380.6693115234375, 测试损失值为176.395263671875
# 第477/500次训练，训练损失值为1372.609619140625, 测试损失值为176.4228973388672
# 第478/500次训练，训练损失值为1378.250244140625, 测试损失值为176.42898559570312
# 第479/500次训练，训练损失值为1374.071533203125, 测试损失值为176.41961669921875
# 第480/500次训练，训练损失值为1378.5560302734375, 测试损失值为176.4219207763672
# 第481/500次训练，训练损失值为1385.5367431640625, 测试损失值为176.40164184570312
# 第482/500次训练，训练损失值为1381.7939453125, 测试损失值为176.44235229492188
# 第483/500次训练，训练损失值为1374.8369140625, 测试损失值为176.46292114257812
# 第484/500次训练，训练损失值为1375.7435302734375, 测试损失值为176.42555236816406
# 第485/500次训练，训练损失值为1391.975830078125, 测试损失值为176.43357849121094
# 第486/500次训练，训练损失值为1378.5546875, 测试损失值为176.43002319335938
# 第487/500次训练，训练损失值为1376.127197265625, 测试损失值为176.42935180664062
# 第488/500次训练，训练损失值为1384.402099609375, 测试损失值为176.44772338867188
# 第489/500次训练，训练损失值为1371.697021484375, 测试损失值为176.4198455810547
# 第490/500次训练，训练损失值为1386.457275390625, 测试损失值为176.41444396972656
# 第491/500次训练，训练损失值为1372.791015625, 测试损失值为176.4697265625
# 第492/500次训练，训练损失值为1378.9488525390625, 测试损失值为176.45367431640625
# 第493/500次训练，训练损失值为1392.51318359375, 测试损失值为176.43836975097656
# 第494/500次训练，训练损失值为1379.58837890625, 测试损失值为176.43702697753906
# 第495/500次训练，训练损失值为1375.5440673828125, 测试损失值为176.45188903808594
# 第496/500次训练，训练损失值为1385.1263427734375, 测试损失值为176.39195251464844
# 第497/500次训练，训练损失值为1380.5947265625, 测试损失值为176.45364379882812
# 第498/500次训练，训练损失值为1378.6282958984375, 测试损失值为176.46617126464844
# 第499/500次训练，训练损失值为1379.71435546875, 测试损失值为176.43690490722656
# 第500/500次训练，训练损失值为1375.55712890625, 测试损失值为176.4792022705078

# %% [markdown]
# ## visualization of the predicted heatmap

# %%
import matplotlib.pyplot as plt
from torch.autograd import Variable

sample_idx = 2
imgs_list = os.listdir(os.path.join(image_path))
orim = Image.open(os.path.join(image_path, imgs_list[sample_idx - 1]))

image1 = transforms(orim)
image1 = Variable(torch.unsqueeze(image1, dim=0).float(), requires_grad=False)

image = image1.to(device)
predict = model(image)
print(predict.shape)
predict_ = predict.view((128, 128, 14)).cpu().detach().numpy()

fig = plt.figure(figsize=(18, 12))
for i in range(14):
    ax1 = fig.add_subplot(3, 5, i+1)
    img = predict_[:,:,i]
    ax1.imshow(img)
plt.show()
# Out:
# torch.Size([1, 14, 128, 128])
